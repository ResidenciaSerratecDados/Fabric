# %%
import pandas as pd
from pyspark.sql import SparkSession
import pyspark.pandas as ps
from pyspark.sql import functions as F
from pyspark.sql.types import FloatType
import numpy as np
# Out:
# StatementMeta(, dbe0759c-d28c-4356-85ac-939f5b4149c4, 26, Finished, Available, Finished)

# %%
df = spark.sql("SELECT * FROM LakeHouse_IBGE_Murilo.petropolis_setores LIMIT 1000")
display(df)
# Out:
# StatementMeta(, dbe0759c-d28c-4356-85ac-939f5b4149c4, 5, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 3cda822e-3aef-4fb1-9a5f-efc711d232b4)

# %%
df_geral = spark.sql("SELECT * FROM LakeHouse_IBGE_Murilo.setoresbasicos")
display(df_geral)
# Out:
# StatementMeta(, dbe0759c-d28c-4356-85ac-939f5b4149c4, 6, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 90e10250-3067-46ed-81a0-f61146bb7f63)

# %%
# Filtrando o DataFrame para incluir apenas os registros de Petrópolis
df_petropolis = df_geral.filter(df_geral["NM_MUN"] == "Petrópolis")

# Exibindo as primeiras linhas do DataFrame filtrado
display(df_petropolis)
# Out:
# StatementMeta(, dbe0759c-d28c-4356-85ac-939f5b4149c4, 7, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, e346bf93-f834-41be-822b-4b5b1745e6e3)

# %%
df_petropolis_pd = df_petropolis.toPandas()
df_petropolis_pd.to_csv(
    "abfss://4d610067-8093-41e5-8082-7cad66a1a874@onelake.dfs.fabric.microsoft.com/1c8200e7-59ed-4bf8-914c-fdaca50c5cd7/Files/petropolis_setores.csv",
    index=False,
    encoding="utf-8"
)
# Out:
# StatementMeta(, dbe0759c-d28c-4356-85ac-939f5b4149c4, 8, Finished, Available, Finished)

# %%
df_pet22 = spark.sql("SELECT * FROM LakeHouse_IBGE_Murilo.petropolis_setores LIMIT 1000")
display(df_pet22)
# Out:
# StatementMeta(, dbe0759c-d28c-4356-85ac-939f5b4149c4, 9, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 86aa4f10-c7b8-43d1-ae35-59b50b2a1630)

# %%
#renomear colunas e converter para float as colunas
'''
df_pet22 = df_pet22 \
    .withColumn('v0001', F.round(F.col('Total_Pessoas').cast(FloatType()), 2)) \
    .withColumn('v0002', F.round(F.col('Total_Domicilios').cast(FloatType()), 2)) \
    .withColumn('v0003', F.round(F.col('Domicilios_Particulares').cast(FloatType()), 2)) \
    .withColumn('v0004', F.round(F.col('Domicilios_Coletivos').cast(FloatType()), 2)) \
    .withColumn('v0005', F.round(F.col('Media_Mor_Dom_Par').cast(FloatType()), 2)) \
    .withColumn('v0006', F.round(F.col('%_Mor_Dom_Par').cast(FloatType()), 2)) \
    .withColumn('v0007', F.round(F.col('Tot_Dom_Part_Ocup').cast(FloatType()), 2))

df_pet22.printSchema()
display(df_pet22)
'''
# Out:
# StatementMeta(, dbe0759c-d28c-4356-85ac-939f5b4149c4, 10, Finished, Available, Finished)
# "\ndf_pet22 = df_pet22     .withColumn('v0001', F.round(F.col('Total_Pessoas').cast(FloatType()), 2))     .withColumn('v0002', F.round(F.col('Total_Domicilios').cast(FloatType()), 2))     .withColumn('v0003', F.round(F.col('Domicilios_Particulares').cast(FloatType()), 2))     .withColumn('v0004', F.round(F.col('Domicilios_Coletivos').cast(FloatType()), 2))     .withColumn('v0005', F.round(F.col('Media_Mor_Dom_Par').cast(FloatType()), 2))     .withColumn('v0006', F.round(F.col('%_Mor_Dom_Par').cast(FloatType()), 2))     .withColumn('v0007', F.round(F.col('Tot_Dom_Part_Ocup').cast(FloatType()), 2))\n\ndf_pet22.printSchema()\ndisplay(df_pet22)\n"

# %%
#Listar as comunidades
fcu_set = df_pet22.select(F.collect_set("NM_FCU").alias("fcu_list")).first()["fcu_list"]
print(fcu_set)
# Out:
# StatementMeta(, dbe0759c-d28c-4356-85ac-939f5b4149c4, 11, Finished, Available, Finished)
# ['Osvaldo Cruz - Valparaíso', 'Vila São Francisco A', 'Madame Machado', 'Duques', 'Rua Bingen 850 - Bingen', 'Morro Florido - Estrada da Saudade', 'São João Batista', 'Vai quem Quer - Vital Brasil', 'Alto Siméria', 'Estrada da Saudade - Veridiano Felix', 'Morro do Neylor', 'Sítio do Pica-Pau', 'Morro do Príncipe', 'Estrada do Paraíso B', 'Comunidade de São Francisco de Assis - Alto da Derrubada', 'Estrada do Paraíso A', 'Vila São Francisco B', 'Leito / BNH Pedro do Rio', 'Alto Independência', 'Espírito Santo', 'Contorno II', 'Cantinho da Esperança', 'Professor João de Deus - Quarteirão Brasileiro', 'Morro da Lenha', 'Comunidade Unidos Venceremos', 'Sargento Boening', 'Comunidade Vitória', '14 Bis Bartolomeu de Gusmão', 'Bonfim Urbano - Corrêas', 'Jacinto Rabelo', 'Contorno I', 'Vila São José - Centro', 'Juiz Castro e Silva', 'Morro do Alemão', 'Rodovia BR-040 - km 79', 'Morro da Oficina - Rua dos Ferroviários', 'Boa Vista', 'Vale do Carangola - Carangola', 'Marujento', 'Morro do Calango', 'Morro da Glória', 'Pedro Ivo', 'Caxambu - Buraco do Caxambu, Loteamento Elísio Alves']

# %%
df_sum = df_pet22.groupBy("NM_FCU") \
    .agg(F.sum("v0001").alias("Residentes")) \
    .filter(F.col("NM_FCU").isNotNull())

df_sorted = df_sum.orderBy(F.col("Residentes").desc())
display(df_sorted)
# Out:
# StatementMeta(, dbe0759c-d28c-4356-85ac-939f5b4149c4, 12, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 0b2317ee-ae51-411b-8428-7a5bdb983bb8)

# %%
#Cálculo Demanda
#Q = n * p * q

#Q = demanda (metade de moradores * preço) = 100 * Q/2
#Q = 50 Q
#n = número de compradores
#p = preço médio
#q = quantidade média de compradores por ano

#Se n for maior que 150, tem potencial para o curso de idiomas
#n = Q/(p * q) = 50Q/(100 * 150)
#n = Q/300
# Out:
# StatementMeta(, dbe0759c-d28c-4356-85ac-939f5b4149c4, 13, Finished, Available, Finished)

# %%
# Converte DataFrame Spark para pandas
comunidade = df_sorted.toPandas()

# Calcula o potencial
comunidade['Potencial'] = (comunidade['Residentes'] / 300).round(0)
#Situação de demanda
comunidade['Classificacao'] = np.where(comunidade['Potencial'] >= 50, 'SIM', 'NÃO')

# Exibe o resultado
display(comunidade)
# Out:
# StatementMeta(, dbe0759c-d28c-4356-85ac-939f5b4149c4, 35, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, c2fb2213-1ea6-45b8-a5c3-6764aa546c5a)

# %%
#Listar os aglomerados
fcu_aglom = df_pet22.select(F.collect_set("NM_AGLOM").alias("fcu_aglom")).first()["fcu_aglom"]
print(fcu_aglom)
# Out:
# StatementMeta(, dbe0759c-d28c-4356-85ac-939f5b4149c4, 15, Finished, Available, Finished)
# ['Comunidade Quilombola Tapera', 'Brejal']

# %%
df_sum2 = df_pet22.groupBy("NM_AGLOM") \
    .agg(F.sum("v0001").alias("Residentes")) \
    .filter(F.col("NM_AGLOM").isNotNull())

df_sorted2 = df_sum2.orderBy(F.col("Residentes").desc())
display(df_sorted2)
# Out:
# StatementMeta(, dbe0759c-d28c-4356-85ac-939f5b4149c4, 16, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 1377d588-296f-492a-b22f-6443f61f0811)

# %%
# Converte DataFrame Spark para pandas
aglomerado = df_sorted2.toPandas()

# Calcula o potencial
aglomerado['Potencial'] = (aglomerado['Residentes'] / 300).round(0)
#Situação de demanda
aglomerado['Classificacao'] = np.where(aglomerado['Potencial'] >= 50, 'SIM', 'NÃO')

# Exibe o resultado
display(aglomerado)
# Out:
# StatementMeta(, dbe0759c-d28c-4356-85ac-939f5b4149c4, 34, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 7f22f146-3da4-46e0-a7a8-2ba76c7601d7)

# %%
#Listar os DISTRITOS
fcu_dist = df_pet22.select(F.collect_set("NM_DIST").alias("fcu_dist")).first()["fcu_dist"]
print(fcu_dist)
# Out:
# StatementMeta(, dbe0759c-d28c-4356-85ac-939f5b4149c4, 17, Finished, Available, Finished)
# ['Cascatinha', 'Itaipava', 'Pedro do Rio', 'Posse', 'Petrópolis']

# %%
df_sum3 = df_pet22.groupBy("NM_DIST") \
    .agg(F.sum("v0001").alias("Residentes")) \
    .filter(F.col("NM_DIST").isNotNull())

df_sorted3 = df_sum3.orderBy(F.col("Residentes").desc())
display(df_sorted3)
# Out:
# StatementMeta(, dbe0759c-d28c-4356-85ac-939f5b4149c4, 18, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 7b586112-f4f7-46a6-b592-6ae228d63338)

# %%
# Converte DataFrame Spark para pandas
distrito = df_sorted3.toPandas()

# Calcula o potencial
distrito['Potencial'] = (distrito['Residentes'] / 300).round(0)
#Situação de demanda
distrito['Classificacao'] = np.where(distrito['Potencial'] >= 50, 'SIM', 'NÃO')

# Exibe o resultado
display(distrito)
# Out:
# StatementMeta(, dbe0759c-d28c-4356-85ac-939f5b4149c4, 33, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 61423f6f-0e9c-41a1-9b99-ae2bed0d4913)

# %%
df800 = spark.sql("SELECT * FROM LakeHouse_IBGE_Murilo.petropolis300 LIMIT 1000")
display(df800)
# Out:
# StatementMeta(, dbe0759c-d28c-4356-85ac-939f5b4149c4, 19, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, ad9ee3aa-3339-4e57-846d-e955cba43093)

# %%
#CÁCULO DA DEMANDA:
#https://pt.slideshare.net/slideshow/clculo-de-demanda/59396535#4
#Ver o potencial para abrir curso de imgles por local
# Out:
# StatementMeta(, dbe0759c-d28c-4356-85ac-939f5b4149c4, -1, Cancelled, , Cancelled)

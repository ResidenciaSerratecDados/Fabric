# %%
import pandas as pd
import numpy as np

# %%
d1960 = pd.read_csv("60.csv", header=None, sep=";")
display(d1960.head(10000))
# Out:
#                                                      0   \
# 0                                      dataset_of_track
# 1     6 Chorale Preludes "Schübler-Chorales": Wachet...
# 2        Carmen: Act I - "Draussen am Wall von Sevilla"
# 3                     Carmen: Act I - "Hier die Order!"
# 4             Carmen: Act II - "Sag. wen erwartest du?"
# ...                                                 ...
# 996                                     You're My World
# 997                        You've Made Me So Very Happy
# 998                    Yuri Approaches Lara's Apartment
# 999                                       Zelda's Theme
# 1000                                          Zero Hour
#
#                                     1                                     2   \
# 0                    dataset_of_artist                        dataset_of_uri
# 1                Johann Sebastian Bach  spotify:track:4dZxCn07QoBsJwDBcjVGx1
# ...

# %%
d1970 = pd.read_csv("70.csv", header=None, sep=";")
display(d1970.head(10000))
# Out:
#                                                      0                    1   \
# 0                                      dataset_of_track    dataset_of_artist
# 1          Der Berg (Aus " Der Watzmann ruft " ) - Live      Wolfgang Ambros
# 2          Evergreen (Love Theme From "A Star Is Born")     Barbra Streisand
# 3     Intrusion des racketteurs noirs dans les maiso...  François de Roubaix
# 4     The Ballad of Sweeney Todd: "Sweeney Pondered ...     Stephen Sondheim
# ...                                                 ...                  ...
# 996                               Young Hearts Run Free         Candi Staton
# 997                          Your Love Is Like A Cancer            Son Seals
# 998                                Your Own Special Way              Genesis
# 999                                    Your Time To Cry            Joe Simon
# 1000                                              Yo-Yo          The Osmonds
#
# ...

# %%
d1980 = pd.read_csv("80.csv", header=None, sep=";")
display(d1980.head(10000))
# Out:
#                                                      0   \
# 0                                      dataset_of_track
# 1     Overture (The Big Race) - From "Pee Wee's Big ...
# 2                  Rapper's Delight - 7" Single Version
# 3              Surrender To Me (From "Tequila Sunrise")
# 4         Symphonie "Mathis der Maler": 1. Engelkonzert
# ...                                                 ...
# 996                                           הפרח בגני
# 997                                      להלה יזיד אקטר
# 998                                           לשיר איתך
# 999                                                נשבע
# 1000                                   עוד דקה את נעלמת
#
#                              1                                     2   \
# 0             dataset_of_artist                        dataset_of_uri
# 1                  Danny Elfman  spotify:track:1P9PYvV5kuZ9dAACp3qSQm
# 2            The Sugarhill Gang  spotify:track:1FnxNtKli7rcB9IU4J8MEg
# ...

# %%
d1990 = pd.read_csv("90.csv", header=None, sep=";")
display(d1990.head(10000))
# Out:
#                                              0                           1   \
# 0                              dataset_of_track           dataset_of_artist
# 1     Don't Cry For Me Argentina (From "Evita")                     Madonna
# 2           I Love Music (From "Carlito's Way")                     Rozalla
# 3                 Let It Go (From "Set It Off")                       Ray J
# 4                          Oscar's "B" Sandwich            Oscar the Grouch
# ...                                         ...                         ...
# 996                                       แพ้ใจ             Mai Charoenpura
# 997                                    ขอจันทร์  Viyada Komarakul Na Nakorn
# 998                                      คงเดิม              Asanee & Wasan
# 999                                    วิมานดิน          Nantida Kaewbuasai
# 1000                                    หยุดเลย                    J Jetrin
#
# ...

# %%
d2000 = pd.read_csv("2000.csv", header=None, sep=";")
display(d2000.head(10000))
# Out:
#                                                      0                  1   \
# 0                                      dataset_of_track  dataset_of_artist
# 1                             Collage #1 ("Blue Suede")       James Tenney
# 2     Deus Passus. "St. Luke Passion": Das ist mein ...      Wolfgang Rihm
# 3     I Won't Say (I'm In Love) - From "Hercules" / ...         Susan Egan
# 4     Look On The Bright Side Of Life (All Things Du...       Monty Python
# ...                                                 ...                ...
# 996                                    You're Beautiful        James Blunt
# 997                            You're Gonna Go Far. Kid      The Offspring
# 998                               You're My Better Half        Keith Urban
# 999                      Zombie Jamboree (Back To Back)    Harry Belafonte
# 1000                                           คนไร้ค่า   Stone Metal Fire
#
# ...

# %%
d2010 = pd.read_csv("2010.csv", header=None, sep=";")
display(d2010.head(10000))
# Out:
#                                                      0                    1   \
# 0                                      dataset_of_track    dataset_of_artist
# 1     Game Of Thrones - From The "Game Of Thrones" S...        Ramin Djawadi
# 2         Glass: Truman Sleeps (From "The Truman Show")         Philip Glass
# 3     Holes In The Sky - From The "Insurgent" Soundt...                  M83
# 4                          Milegi Milegi (From "Stree")           Mika Singh
# ...                                                 ...                  ...
# 996                                       Your Disposal  Cattle Decapitation
# 997                                               Yours    Russell Dickerson
# 998                                              Zombie          Chief State
# 999                      我がままなハイヒール - Non Stop Mix ver.                  秋元薫
# 1000                                               胜者为王                   窒息
#
# ...

# %%
df_decadas=pd.concat([d1960,d1970,d1980,d1990,d2000,d2010])
display(df_decadas.head(60000))
# Out:
#                                                      0   \
# 0                                      dataset_of_track
# 1     6 Chorale Preludes "Schübler-Chorales": Wachet...
# 2        Carmen: Act I - "Draussen am Wall von Sevilla"
# 3                     Carmen: Act I - "Hier die Order!"
# 4             Carmen: Act II - "Sag. wen erwartest du?"
# ...                                                 ...
# 996                                       Your Disposal
# 997                                               Yours
# 998                                              Zombie
# 999                      我がままなハイヒール - Non Stop Mix ver.
# 1000                                               胜者为王
#
#                                     1                                     2   \
# 0                    dataset_of_artist                        dataset_of_uri
# 1                Johann Sebastian Bach  spotify:track:4dZxCn07QoBsJwDBcjVGx1
# ...

# %%
df_decadas.to_csv("saida_6decadas_colab.csv", index=False, sep=";", encoding="utf-8-sig")
